# %%
import time
import datetime

import pandas as pd
import xarray as xr
import numpy as np
# import statsmodels.formula.api as smf
# from statsmodels.iolib.smpickle import load_pickle

import comp_utils

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pickle as pkl

# %%
condition = True
intervals = 600 # 3600 # N시간 마다

rebase_api_client = comp_utils.RebaseAPI(api_key = open("team_key.txt").read()[:-1])

while condition:
    # 1시간 단위로 아래 과정을 반복
    # 파일안에 ref_datetime의 최소값이 (00시, 12시, 18시)인 경우에 해당 데이터를 처리하는 과정
    
    try:
        
        # api 처리 과정 코드
        #### to-do ####
        latest_ncep_Hornsea1 = comp_utils.weather_df_to_xr(rebase_api_client.get_hornsea_gfs()).to_dataframe().reset_index(drop=False)
        latest_ncep_solar = comp_utils.weather_df_to_xr(rebase_api_client.get_pes10_nwp("NCEP_GFS")).to_dataframe().reset_index(drop=False)
        
#         ref_datetime = pd.dataFrame(api...)['ref_datetime']
#         min_ref_datetime = min(ref_datetime)

        ref_datetime = latest_ncep_Hornsea1['ref_datetime']
        min_ref_datetime = min(ref_datetime)
        ###############
        
        if min_ref_datetime.hour == 0:
            # file 저장
            date_name = str(min(latest_ncep_Hornsea1["ref_datetime"]).year) + str(min(latest_ncep_Hornsea1["ref_datetime"]).month) + str(min(latest_ncep_Hornsea1["ref_datetime"]).day)
            
            ncep_hornsea_file_name = "ncep_gfs_hornsea_1_" + date_name + "_" + str(min_ref_datetime.hour)
            ncep_pes10_file_name = "ncep_gfs_pes10_" + date_name + "_" + str(min_ref_datetime.hour)
            
            #### to-do ####
            latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
            latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            # if 문으로 NaN값 있을 때 저장 X
#             if latest_ncep_Hornsea1.shape[0] == 1881 and latest_ncep_solar.shape[0] == 4180:
#                 #### to-do ####
#                 latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
#                 latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            ###############
        elif min_ref_datetime.hour == 6:
            # file 저장
            date_name = str(min(latest_ncep_Hornsea1["ref_datetime"]).year) + str(min(latest_ncep_Hornsea1["ref_datetime"]).month) + str(min(latest_ncep_Hornsea1["ref_datetime"]).day)
            
            ncep_hornsea_file_name = "ncep_gfs_hornsea_1_" + date_name + "_" + str(min_ref_datetime.hour)
            ncep_pes10_file_name = "ncep_gfs_pes10_" + date_name + "_" + str(min_ref_datetime.hour)
            
            #### to-do ####      
            latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
            latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            # if 문으로 NaN값 있을 때 저장 X
#             if latest_ncep_Hornsea1.shape[0] == 1881 and latest_ncep_solar.shape[0] == 4180:
#                 #### to-do ####
#                 latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
#                 latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            ###############
        elif min_ref_datetime.hour == 12:
            # file 저장
            date_name = str(min(latest_ncep_Hornsea1["ref_datetime"]).year) + str(min(latest_ncep_Hornsea1["ref_datetime"]).month) + str(min(latest_ncep_Hornsea1["ref_datetime"]).day)
            
            ncep_hornsea_file_name = "ncep_gfs_hornsea_1_" + date_name + "_" + str(min_ref_datetime.hour)
            ncep_pes10_file_name = "ncep_gfs_pes10_" + date_name + "_" + str(min_ref_datetime.hour)
            
            #### to-do ####            
            latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
            latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            # if 문으로 NaN값 있을 때 저장 X
#             if latest_ncep_Hornsea1.shape[0] == 1881 and latest_ncep_solar.shape[0] == 4180:
#                 #### to-do ####
#                 latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
#                 latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            
            ###############
        elif min_ref_datetime.hour == 18:
            # file 저장
            date_name = str(min(latest_ncep_Hornsea1["ref_datetime"]).year) + str(min(latest_ncep_Hornsea1["ref_datetime"]).month) + str(min(latest_ncep_Hornsea1["ref_datetime"]).day)

            ncep_hornsea_file_name = "ncep_gfs_hornsea_1_" + date_name + "_" + str(min_ref_datetime.hour)
            ncep_pes10_file_name = "ncep_gfs_pes10_" + date_name + "_" + str(min_ref_datetime.hour)
            
            #### to-do ####
            latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
            latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            # if 문으로 NaN값 있을 때 저장 X
#             if latest_ncep_Hornsea1.shape[0] == 1881 and latest_ncep_solar.shape[0] == 4180:
#                 #### to-do ####
#                 latest_ncep_Hornsea1.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_hornsea_file_name+"_raw.csv")
#                 latest_ncep_solar.to_csv("./updated_weather_forecast_data/NCEP_GFS/"+ncep_pes10_file_name+"_raw.csv")
            
            ###############
        else:
            pass
    
        # 1시간 (3600s) 단위 sleep (단위 설정 필요)
        time.sleep(intervals)
        
    except Exception as e:
        # recursive로 해결하면 좋을듯\
        print(f"Error at UK's time ({now_uk})")
        print("아 이거 뭔데 이거", e)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
